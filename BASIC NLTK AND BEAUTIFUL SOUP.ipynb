# %% [markdown]
# ## Import Packages

# %%
import re
from nltk import word_tokenize, sent_tokenize, ngrams, pos_tag, RegexpParser
from nltk.corpus import stopwords
from collections import Counter
from bs4 import BeautifulSoup
from bs4.element import Comment
from urllib import request
from pprint import pprint

# %% [markdown]
# ## 1. Use urllib or requests package to read this CNBC article through its URL link.
#
# ## 2. Use BeautifulSoup (Links to an external site.) or another HTML parsing package to extract text from the article.

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

url = 'https://www.cnbc.com/2019/01/17/netflix-price-hike-helps-disney-upcoming-streaming-service-analyst.html'
html = request.urlopen(url).read()
result = text_from_html(html)

# %% [markdown]
# ## 3. Use re (regular expression) package to:
# ### 3a.  Find all matches of $ amounts in the article

# %%
re.findall(r'\$\d+\w', result)
# Out:
# ['$325', '$351']

# %% [markdown]
# ### 3b. Substitute all numbers with # character and print the output

# %%
print(re.sub('[0-9]', '#', result))
# Out:
# Skip Navigation Markets Pre-Markets U.S. Markets Currencies Cryptocurrency Futures & Commodities Bonds Funds & ETFs Business Economy Finance Health & Science Media Real Estate Energy Climate Transportation Industrials Retail Wealth Life Small Business Investing Invest In You Personal Finance Fintech Financial Advisors Trading Nation Options Action ETF Street Buffett Archive Earnings Trader Talk Tech Cybersecurity Enterprise Internet Media Mobile Social Media CNBC Disruptor ## Tech Guide Politics White House Policy Defense Congress Equity and Opportunity CNBC TV Live TV Live Audio Business Day Shows The News with Shepard Smith Entertainment Shows Full Episodes Latest Video Top Video CEO Interviews CNBC Documentaries CNBC Podcasts CNBC World Digital Originals Live TV Schedule Watchlist PRO Pro News Pro Live Subscribe Sign In Menu Make It USA INTL watch live Search quotes, news & videos SIGN IN Markets Pre-Markets U.S. Markets Currencies Cryptocurrency Futures & Commodities Bonds Funds & ETFs Business Economy Finance Health & Science Media Real Estate Energy Climate Transportation Industrials Retail Wealth Life Small Business Investing Invest In You Personal Finance Fintech Financial Advisors Trading Nation Options Action ETF Street Buffett Archive Earnings Trader Talk Tech Cybersecurity Enterprise Internet Media Mobile Social Media CNBC Disruptor ## Tech Guide Politics White House Policy Defense Congress Equity and Opportunity CNBC TV Live TV Live Audio Business Day Shows The News with Shepard Smith Entertainment Shows Full Episodes Latest Video Top Video CEO Interviews CNBC Documentaries CNBC Podcasts CNBC World Digital Originals Live TV Schedule Watchlist PRO Pro News Pro Live Subscribe Sign In Menu Tech Netflix's price hike is a 'Catch-##'  that actually helps Disney's upcoming streaming service Published Thu, Jan ## #### #:## PM EST Updated Thu, Jan ## #### #:## PM EST Tyler Clifford @_TylerTheTyler_ Share Share Article via Facebook Share Article via Twitter Share Article via LinkedIn Share Article via Email Key Points Netflix subscription price hike is a "key dilemma" that makes future competitors like Disney more viable, New Constructs CEO David Trainer says. However, Aegis Capital's Victory Anthony sees the Netflix price increase as extra money to invest in more original content or pad the bottom line. VIDEO #:## ##:## Netflix's decision to raise prices is a Catch-##, says New Constructs' David Trainer Closing Bell Disney will have a competitive advantage over Netflix when the entertainment conglomerate launches a competing video streaming platform later this year, according to Wall Street analyst David Trainer. "[Disney's] got the ability to merchandise, which is another way to monetize content in a way that Netflix does not have," Trainer said on CNBC's "Closing Bell" Wednesday. He's chief of the New Constructs research firm. Netflix increased its subscription prices Tuesday, sending the stock up #.# percent that day as well. However, Trainer called it a "key dilemma" for the company and it "makes their competitors more viable." The dilemma, he explained, is that the streaming company relies too much on its subscribers to generate revenue. "It's a Catch-## for a business model that, when you look at the fundamentals, really just doesn't work," Trainer alleged. VIDEO #:## ##:## Snap should 'take check from anyone who comes knocking', says expert Squawk Alley The Netflix price increase for U.S. subscribers ranges between ## percent and ## percent, which Victory Anthony of Aegis Capital sees as a positive, a view generally shared by much of the investment community. "It's all profit for the price increase and so they can either use that to invest in more original content or they can let that drop down to their down to the bottom line," Anthony said on "Squawk Alley" Thursday. Aegis put a hold on Neflix at current levels because it's about # percent higher than Anthony's price target of $###. The stock was trading steady ar ...

# %% [markdown]
# ### 3c. Count (using regular expressions) ”Netflix” and “Disney” mentions

# %%
len(re.findall('Disney|Netflix', result))
# Out:
# 20

# %% [markdown]
# ## 4. Use NTLK and/or Spacy tokenization features to:

# %% [markdown]
# ### 4a. Tokenize sentences and words

# %%
sentences = sent_tokenize(result)
words = word_tokenize(result)

# %% [markdown]
# ### 4b. Remove all English stop words

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [w for w in words if not w.lower() in stop_words]

# %% [markdown]
# ### 4c. List and count n-grams for any given input n

# %%
def countNGrams(sentence, n):
    return Counter(ngrams(sentence,n))
countNGrams(filtered_words, 3)
# Out:
# Counter({('Skip', 'Navigation', 'Markets'): 1,
#          ('Navigation', 'Markets', 'Pre-Markets'): 1,
#          ('Markets', 'Pre-Markets', 'U.S.'): 2,
#          ('Pre-Markets', 'U.S.', 'Markets'): 2,
#          ('U.S.', 'Markets', 'Currencies'): 2,
#          ('Markets', 'Currencies', 'Cryptocurrency'): 2,
#          ('Currencies', 'Cryptocurrency', 'Futures'): 2,
#          ('Cryptocurrency', 'Futures', '&'): 2,
#          ('Futures', '&', 'Commodities'): 2,
#          ('&', 'Commodities', 'Bonds'): 2,
#          ('Commodities', 'Bonds', 'Funds'): 2,
#          ('Bonds', 'Funds', '&'): 2,
#          ('Funds', '&', 'ETFs'): 2,
#          ('&', 'ETFs', 'Business'): 2,
#          ('ETFs', 'Business', 'Economy'): 2,
#          ('Business', 'Economy', 'Finance'): 2,
#          ('Economy', 'Finance', 'Health'): 2,
#          ('Finance', 'Health', '&'): 2,
#          ('Health', '&', 'Science'): 2,
#          ('&', 'Science', 'Media'): 2,
#          ('Science', 'Media', 'Real'): 2,
#          ('Media', 'Real', 'Estate'): 2,
#          ('Real', 'Estate', 'Energy'): 2,
#          ('Estate', 'Energy', 'Climate'): 2,
#          ('Energy', 'Climate', 'Transportation'): 2,
#          ('Climate', 'Transportation', 'Industrials'): 2,
#          ('Transportation', 'Industrials', 'Retail'): 2,
#          ('Industrials', 'Retail', 'Wealth'): 2,
#          ('Retail', 'Wealth', 'Life'): 2,
#          ('Wealth', 'Life', 'Small'): 2,
#          ('Life', 'Small', 'Business'): 2,
#          ('Small', 'Business', 'Investing'): 2,
#          ('Business', 'Investing', 'Invest'): 2,
#          ('Investing', 'Invest', 'Personal'): 2,
#          ('Invest', 'Personal', 'Finance'): 2,
#          ('Personal', 'Finance', 'Fintech'): 2,
#          ('Finance', 'Fintech', 'Financial'): 2,
#          ('Fintech', 'Financial', 'Advisors'): 2,
#          ('Financial', 'Advisors', 'Trading'): 2,
#          ('Advisors', 'Trading', 'Nation'): 2,
#          ('Trading', 'Nation', 'Options'): 2,
#          ('Nation', 'Options', 'Action'): 2,
#          ('Options', 'Action', 'ETF'): 2,
#          ('Action', 'ETF', 'Street'): 2,
#          ('ETF', 'Street', 'Buffett'): 2,
#          ('Street', 'Buffett', 'Archive'): 2,
#          ('Buffett', 'Archive', 'Earnings'): 2,
#          ('Archive', 'Earnings', 'Trader'): 2,
#          ('Earnings', 'Trader', 'Talk'): 2,
#          ('Trader', 'Talk', 'Tech'): 2,
#          ('Talk', 'Tech', 'Cybersecurity'): 2,
#          ('Tech', 'Cybersecurity', 'Enterprise'): 2,
#          ('Cybersecurity', 'Enterprise', 'Internet'): 2,
#          ('Enterprise', 'Internet', 'Media'): 2,
#          ('Internet', 'Media', 'Mobile'): 2,
#          ('Media', 'Mobile', 'Social'): 2,
#          ('Mobile', 'Social', 'Media'): 2,
#          ('Social', 'Media', 'CNBC'): 2,
#          ('Media', 'CNBC', 'Disruptor'): 2,
#          ('CNBC', 'Disruptor', '50'): 2,
#          ('Disruptor', '50', 'Tech'): 2,
#          ('50', 'Tech', 'Guide'): 2,
#          ('Tech', 'Guide', 'Politics'): 2,
#          ('Guide', 'Politics', 'White'): 2,
#          ('Politics', 'White', 'House'): 2,
#          ('White', 'House', 'Policy'): 2,
#          ('House', 'Policy', 'Defense'): 2,
#          ('Policy', 'Defense', 'Congress'): 2,
#          ('Defense', 'Congress', 'Equity'): 2,
#          ('Congress', 'Equity', 'Opportunity'): 2,
#          ('Equity', 'Opportunity', 'CNBC'): 2,
#          ('Opportunity', 'CNBC', 'TV'): 2,
#          ('CNBC', 'TV', 'Live'): 2,
#          ('TV', 'Live', 'TV'): 2,
#          ('Live', 'TV', 'Live'): 2,
#          ('TV', 'Live', 'Audio'): 2,
#          ('Live', 'Audio', 'Business'): 2,
#          ('Audio', 'Business', 'Day'): 2,
#          ('Business', 'Day', 'Shows'): 2,
#          ('Day', 'Shows', 'News'): 2,
#          ('Shows', 'News', 'Shepard'): 2,
#          ('News', 'Shepard', 'Smith'): 2,
#          ('Shepard', 'Smith', 'Entertainment'): 2,
#          ('Smith', 'Entertainment', 'Shows'): 2,
#          ('Entertainment', 'Shows', 'Full'): 2,
#          ('Shows', 'Full', 'Episodes'): 2,
#          ('Full', 'Episodes', 'Latest'): 2,
#          ('Episodes', 'Latest', 'Video'): 2,
#          ('Latest', 'Video', 'Top'): 2,
#          ('Video', 'Top', 'Video'): 2,
#          ('Top', 'Video', 'CEO'): 2,
#          ('Video', 'CEO', 'Interviews'): 2,
#          ('CEO', 'Interviews', 'CNBC'): 2,
#          ('Interviews', 'CNBC', 'Documentaries'): 2,
#          ('CNBC', 'Documentaries', 'CNBC'): 2,
#          ('Documentaries', 'CNBC', 'Podcasts'): 2,
#          ('CNBC', 'Podcasts', 'CNBC'): 2,
#          ('Podcasts', 'CNBC', 'World'): 2,
#          ('CNBC', 'World', 'Digital'): 2,
#          ('World', 'Digital', 'Originals'): 2,
#          ('Digital', 'Originals', 'Live'): 2,
#          ('Originals', 'Live', 'TV'): 2,
#          ('Live', 'TV', 'Schedule'): 2,
#          ('TV', 'Schedule', 'Watchlist'): 2,
#          ('Schedule', 'Watchlist', 'PRO'): 2,
#          ('Watchlist', 'PRO', 'Pro'): 2,
#          ('PRO', 'Pro', 'News'): 2,
#          ('Pro', 'News', 'Pro'): 2,
#          ('News', 'Pro', 'Live'): 2,
#          ('Pro', 'Live', 'Subscribe'): 2,
#          ('Live', 'Subscribe', 'Sign'): 2,
#          ('Subscribe', 'Sign', 'Menu'): 2,
#          ('Sign', 'Menu', 'Make'): 1,
#          ('Menu', 'Make', 'USA'): 1,
#          ('Make', 'USA', 'INTL'): 1,
#          ('USA', 'INTL', 'watch'): 1,
#          ('INTL', 'watch', 'live'): 1,
#          ('watch', 'live', 'Search'): 1,
#          ('live', 'Search', 'quotes'): 1,
#          ('Search', 'quotes', ','): 1,
#          ('quotes', ',', 'news'): 1,
#          (',', 'news', '&'): 1,
#          ('news', '&', 'videos'): 1,
#          ('&', 'videos', 'SIGN'): 1,
#          ('videos', 'SIGN', 'Markets'): 1,
#          ('SIGN', 'Markets', 'Pre-Markets'): 1,
#          ('Sign', 'Menu', 'Tech'): 1,
#          ('Menu', 'Tech', 'Netflix'): 1,
#          ('Tech', 'Netflix', "'s"): 1,
#          ('Netflix', "'s", 'price'): 1,
#          ("'s", 'price', 'hike'): 1,
#          ('price', 'hike', "'Catch-22"): 1,
#          ('hike', "'Catch-22", "'"): 1,
#          ("'Catch-22", "'", 'actually'): 1,
#          ("'", 'actually', 'helps'): 1,
#          ('actually', 'helps', 'Disney'): 1,
#          ('helps', 'Disney', "'s"): 1,
#          ('Disney', "'s", 'upcoming'): 1,
#          ("'s", 'upcoming', 'streaming'): 1,
#          ('upcoming', 'streaming', 'service'): 1,
#          ('streaming', 'service', 'Published'): 1,
#          ('service', 'Published', 'Thu'): 1,
#          ('Published', 'Thu', ','): 1,
#          ('Thu', ',', 'Jan'): 2,
#          (',', 'Jan', '17'): 2,
#          ('Jan', '17', '2019'): 2,
#          ('17', '2019', '1:04'): 1,
#          ('2019', '1:04', 'PM'): 1,
#          ('1:04', 'PM', 'EST'): 1,
#          ('PM', 'EST', 'Updated'): 1,
#          ('EST', 'Updated', 'Thu'): 1,
#          ('Updated', 'Thu', ','): 1,
#          ('17', '2019', '1:42'): 1,
#          ('2019', '1:42', 'PM'): 1,
#          ('1:42', 'PM', 'EST'): 1,
#          ('PM', 'EST', 'Tyler'): 1,
#          ('EST', 'Tyler', 'Clifford'): 1,
#          ('Tyler', 'Clifford', '@'): 1,
#          ('Clifford', '@', '_TylerTheTyler_'): 1,
#          ('@', '_TylerTheTyler_', 'Share'): 1,
#          ('_TylerTheTyler_', 'Share', 'Share'): 1,
#          ('Share', 'Share', 'Article'): 1,
#          ('Share', 'Article', 'via'): 4,
#          ('Article', 'via', 'Facebook'): 1,
#          ('via', 'Facebook', 'Share'): 1,
#          ('Facebook', 'Share', 'Article'): 1,
#          ('Article', 'via', 'Twitter'): 1,
#          ('via', 'Twitter', 'Share'): 1,
#          ('Twitter', 'Share', 'Article'): 1,
#          ('Article', 'via', 'LinkedIn'): 1,
#          ('via', 'LinkedIn', 'Share'): 1,
#          ('LinkedIn', 'Share', 'Article'): 1,
#          ('Article', 'via', 'Email'): 1,
#          ('via', 'Email', 'Key'): 1,
#          ('Email', 'Key', 'Points'): 1,
#          ('Key', 'Points', 'Netflix'): 1,
#          ('Points', 'Netflix', 'subscription'): 1,
#          ('Netflix', 'subscription', 'price'): 1,
#          ('subscription', 'price', 'hike'): 1,
#          ('price', 'hike', '``'): 1,
#          ('hike', '``', 'key'): 1,
#          ('``', 'key', 'dilemma'): 2,
#          ('key', 'dilemma', "''"): 2,
#          ('dilemma', "''", 'makes'): 1,
#          ("''", 'makes', 'future'): 1,
#          ('makes', 'future', 'competitors'): 1,
#          ('future', 'competitors', 'like'): 1,
#          ('competitors', 'like', 'Disney'): 1,
#          ('like', 'Disney', 'viable'): 1,
#          ('Disney', 'viable', ','): 1,
#          ('viable', ',', 'New'): 1,
#          (',', 'New', 'Constructs'): 1,
#          ('New', 'Constructs', 'CEO'): 1,
#          ('Constructs', 'CEO', 'David'): 1,
#          ('CEO', 'David', 'Trainer'): 1,
#          ('David', 'Trainer', 'says'): 1,
#          ('Trainer', 'says', '.'): 1,
#          ('says', '.', 'However'): 1,
#          ('.', 'However', ','): 2,
#          ('However', ',', 'Aegis'): 1,
#          (',', 'Aegis', 'Capital'): 1,
#          ('Aegis', 'Capital', "'s"): 1,
#          ('Capital', "'s", 'Victory'): 1,
#          ("'s", 'Victory', 'Anthony'): 1,
#          ('Victory', 'Anthony', 'sees'): 1,
#          ('Anthony', 'sees', 'Netflix'): 1,
#          ('sees', 'Netflix', 'price'): 1,
#          ('Netflix', 'price', 'increase'): 2,
#          ('price', 'increase', 'extra'): 1,
#          ('increase', 'extra', 'money'): 1,
#          ('extra', 'money', 'invest'): 1,
#          ('money', 'invest', 'original'): 1,
#          ('invest', 'original', 'content'): 2,
#          ('original', 'content', 'pad'): 1,
#          ('content', 'pad', 'bottom'): 1,
#          ('pad', 'bottom', 'line'): 1,
#          ('bottom', 'line', '.'): 1,
#          ('line', '.', 'VIDEO'): 1,
#          ('.', 'VIDEO', '6:10'): 1,
#          ('VIDEO', '6:10', '06:10'): 1,
#          ('6:10', '06:10', 'Netflix'): 1,
#          ('06:10', 'Netflix', "'s"): 1,
#          ('Netflix', "'s", 'decision'): 1,
#          ("'s", 'decision', 'raise'): 1,
#          ('decision', 'raise', 'prices'): 1,
#          ('raise', 'prices', 'Catch-22'): 1,
#          ('prices', 'Catch-22', ','): 1,
#          ('Catch-22', ',', 'says'): 1,
#          (',', 'says', 'New'): 1,
#          ('says', 'New', 'Constructs'): 1,
#          ('New', 'Constructs', "'"): 2,
#          ('Constructs', "'", 'David'): 1,
#          ("'", 'David', 'Trainer'): 1,
#          ('David', 'Trainer', 'Closing'): 1,
#          ('Trainer', 'Closing', 'Bell'): 1,
#          ('Closing', 'Bell', 'Disney'): 1,
#          ('Bell', 'Disney', 'competitive'): 1,
#          ('Disney', 'competitive', 'advantage'): 1,
#          ('competitive', 'advantage', 'Netflix'): 1,
#          ('advantage', 'Netflix', 'entertainment'): 1,
#          ('Netflix', 'entertainment', 'conglomerate'): 1,
#          ('entertainment', 'conglomerate', 'launches'): 1,
#          ('conglomerate', 'launches', 'competing'): 1,
#          ('launches', 'competing', 'video'): 1,
#          ('competing', 'video', 'streaming'): 1,
#          ('video', 'streaming', 'platform'): 1,
#          ('streaming', 'platform', 'later'): 1,
#          ('platform', 'later', 'year'): 1,
#          ('later', 'year', ','): 1,
#          ('year', ',', 'according'): 1,
#          (',', 'according', 'Wall'): 1,
#          ('according', 'Wall', 'Street'): 1,
#          ('Wall', 'Street', 'analyst'): 1,
#          ('Street', 'analyst', 'David'): 1,
#          ('analyst', 'David', 'Trainer'): 1,
#          ('David', 'Trainer', '.'): 1,
#          ('Trainer', '.', '``'): 1,
#          ('.', '``', '['): 1,
#          ('``', '[', 'Disney'): 1,
#          ('[', 'Disney', "'s"): 1,
#          ('Disney', "'s", ']'): 1,
#          ("'s", ']', 'got'): 1,
#          (']', 'got', 'ability'): 1,
#          ('got', 'ability', 'merchandise'): 1,
#          ('ability', 'merchandise', ','): 1,
#          ('merchandise', ',', 'another'): 1,
#          (',', 'another', 'way'): 1,
#          ('another', 'way', 'monetize'): 1,
#          ('way', 'monetize', 'content'): 1,
#          ('monetize', 'content', 'way'): 1,
#          ('content', 'way', 'Netflix'): 1,
#          ('way', 'Netflix', ','): 1,
#          ('Netflix', ',', "''"): 1,
#          (',', "''", 'Trainer'): 2,
#          ("''", 'Trainer', 'said'): 1,
#          ('Trainer', 'said', 'CNBC'): 1,
#          ('said', 'CNBC', "'s"): 1,
#          ('CNBC', "'s", '``'): 1,
#          ("'s", '``', 'Closing'): 1,
#          ('``', 'Closing', 'Bell'): 1,
#          ('Closing', 'Bell', "''"): 1,
#          ('Bell', "''", 'Wednesday'): 1,
#          ("''", 'Wednesday', '.'): 1,
#          ('Wednesday', '.', "'s"): 1,
#          ('.', "'s", 'chief'): 1,
#          ("'s", 'chief', 'New'): 1,
#          ('chief', 'New', 'Constructs'): 1,
#          ('New', 'Constructs', 'research'): 1,
#          ('Constructs', 'research', 'firm'): 1,
#          ('research', 'firm', '.'): 1,
#          ('firm', '.', 'Netflix'): 1,
#          ('.', 'Netflix', 'increased'): 1,
#          ('Netflix', 'increased', 'subscription'): 1,
#          ('increased', 'subscription', 'prices'): 1,
#          ('subscription', 'prices', 'Tuesday'): 1,
#          ('prices', 'Tuesday', ','): 1,
#          ('Tuesday', ',', 'sending'): 1,
#          (',', 'sending', 'stock'): 1,
#          ('sending', 'stock', '6.5'): 1,
#          ('stock', '6.5', 'percent'): 1,
#          ('6.5', 'percent', 'day'): 1,
#          ('percent', 'day', 'well'): 1,
#          ('day', 'well', '.'): 1,
#          ('well', '.', 'However'): 1,
#          ('However', ',', 'Trainer'): 1,
#          (',', 'Trainer', 'called'): 1,
#          ('Trainer', 'called', '``'): 1,
#          ('called', '``', 'key'): 1,
#          ('dilemma', "''", 'company'): 1,
#          ("''", 'company', '``'): 1,
#          ('company', '``', 'makes'): 1,
#          ('``', 'makes', 'competitors'): 1,
#          ('makes', 'competitors', 'viable'): 1,
#          ('competitors', 'viable', '.'): 1,
#          ('viable', '.', "''"): 1,
#          ('.', "''", 'dilemma'): 1,
#          ("''", 'dilemma', ','): 1,
#          ('dilemma', ',', 'explained'): 1,
#          (',', 'explained', ','): 1,
#          ('explained', ',', 'streaming'): 1,
#          (',', 'streaming', 'company'): 1,
#          ('streaming', 'company', 'relies'): 1,
#          ('company', 'relies', 'much'): 1,
#          ('relies', 'much', 'subscribers'): 1,
#          ('much', 'subscribers', 'generate'): 1,
#          ('subscribers', 'generate', 'revenue'): 1,
#          ('generate', 'revenue', '.'): 1,
#          ('revenue', '.', '``'): 1,
#          ('.', '``', "'s"): 2,
#          ('``', "'s", 'Catch-22'): 1,
#          ("'s", 'Catch-22', 'business'): 1,
#          ('Catch-22', 'business', 'model'): 1,
#          ('business', 'model', ','): 1,
#          ('model', ',', 'look'): 1,
#          (',', 'look', 'fundamentals'): 1,
#          ('look', 'fundamentals', ','): 1,
#          ('fundamentals', ',', 'really'): 1,
#          (',', 'really', "n't"): 1,
#          ('really', "n't", 'work'): 1,
#          ("n't", 'work', ','): 1,
#          ('work', ',', "''"): 1,
#          ("''", 'Trainer', 'alleged'): 1,
#          ('Trainer', 'alleged', '.'): 1,
#          ('alleged', '.', 'VIDEO'): 1,
#          ('.', 'VIDEO', '5:21'): 1,
#          ('VIDEO', '5:21', '05:21'): 1,
#          ('5:21', '05:21', 'Snap'): 1,
#          ('05:21', 'Snap', "'take"): 1,
#          ('Snap', "'take", 'check'): 1,
#          ("'take", 'check', 'anyone'): 1,
#          ('check', 'anyone', 'comes'): 1,
#          ('anyone', 'comes', 'knocking'): 1,
#          ('comes', 'knocking', "'"): 1,
#          ('knocking', "'", ','): 1,
#          ("'", ',', 'says'): 1,
#          (',', 'says', 'expert'): 1,
#          ('says', 'expert', 'Squawk'): 1,
#          ('expert', 'Squawk', 'Alley'): 1,
#          ('Squawk', 'Alley', 'Netflix'): 1,
#          ('Alley', 'Netflix', 'price'): 1,
#          ('price', 'increase', 'U.S.'): 1,
#          ('increase', 'U.S.', 'subscribers'): 1,
#          ('U.S.', 'subscribers', 'ranges'): 1,
#          ('subscribers', 'ranges', '13'): 1,
#          ('ranges', '13', 'percent'): 1,
#          ('13', 'percent', '18'): 1,
#          ('percent', '18', 'percent'): 1,
#          ('18', 'percent', ','): 1,
#          ('percent', ',', 'Victory'): 1,
#          (',', 'Victory', 'Anthony'): 1,
#          ('Victory', 'Anthony', 'Aegis'): 1,
#          ('Anthony', 'Aegis', 'Capital'): 1,
#          ('Aegis', 'Capital', 'sees'): 1,
#          ('Capital', 'sees', 'positive'): 1,
#          ('sees', 'positive', ','): 1,
#          ('positive', ',', 'view'): 1,
#          (',', 'view', 'generally'): 1,
#          ('view', 'generally', 'shared'): 1,
#          ('generally', 'shared', 'much'): 1,
#          ('shared', 'much', 'investment'): 1,
#          ('much', 'investment', 'community'): 1,
#          ('investment', 'community', '.'): 1,
#          ('community', '.', '``'): 1,
#          ('``', "'s", 'profit'): 1,
#          ("'s", 'profit', 'price'): 1,
#          ('profit', 'price', 'increase'): 1,
#          ('price', 'increase', 'either'): 1,
#          ('increase', 'either', 'use'): 1,
#          ('either', 'use', 'invest'): 1,
#          ('use', 'invest', 'original'): 1,
#          ('original', 'content', 'let'): 1,
#          ('content', 'let', 'drop'): 1,
#          ('let', 'drop', 'bottom'): 1,
#          ('drop', 'bottom', 'line'): 1,
#          ('bottom', 'line', ','): 1,
#          ('line', ',', "''"): 1,
#          (',', "''", 'Anthony'): 1,
#          ("''", 'Anthony', 'said'): 1,
#          ('Anthony', 'said', '``'): 1,
#          ('said', '``', 'Squawk'): 1,
#          ('``', 'Squawk', 'Alley'): 1,
#          ('Squawk', 'Alley', "''"): 1,
#          ('Alley', "''", 'Thursday'): 1,
#          ("''", 'Thursday', '.'): 1,
#          ('Thursday', '.', 'Aegis'): 1,
#          ('.', 'Aegis', 'put'): 1,
#          ('Aegis', 'put', 'hold'): 1,
#          ('put', 'hold', 'Neflix'): 1,
#          ('hold', 'Neflix', 'current'): 1,
#          ('Neflix', 'current', 'levels'): 1,
#          ('current', 'levels', "'s"): 1,
#          ('levels', "'s", '8'): 1,
#          ("'s", '8', 'percent'): 1,
#          ('8', 'percent', 'higher'): 1,
#          ('percent', 'higher', 'Anthony'): 1,
#          ('higher', 'Anthony', "'s"): 1,
#          ('Anthony', "'s", 'price'): 1,
#          ("'s", 'price', 'target'): 1,
#          ('price', 'target', '$'): 1,
#          ('target', '$', '325'): 1,
#          ('$', '325', '.'): 1,
#          ('325', '.', 'stock'): 1,
#          ('.', 'stock', 'trading'): 1,
#          ('stock', 'trading', 'steady'): 1,
#          ('trading', 'steady', 'around'): 1,
#          ('steady', 'around', '$'): 1,
#          ('around', '$', '351'): 1,
#          ('$', '351', 'midday'): 1,
#          ('351', 'midday', 'Thursday'): 1,
#          ('midday', 'Thursday', ','): 1,
#          ('Thursday', ',', '50'): 1,
#          (',', '50', 'percent'): 1,
#          ('50', 'percent', 'since'): 1,
#          ('percent', 'since', 'Christmas'): 1,
#          ('since', 'Christmas', 'Eve'): 1,
#          ('Christmas', 'Eve', 'washout'): 1,
#          ('Eve', 'washout', '.'): 1,
#          ('washout', '.', 'Netflix'): 1,
#          ('.', 'Netflix', 'releases'): 1,
#          ('Netflix', 'releases', 'fourth'): 1,
#          ('releases', 'fourth', 'quarter'): 1,
#          ('fourth', 'quarter', 'earnings'): 1,
#          ('quarter', 'earnings', 'bell'): 1,
#          ('earnings', 'bell', 'Thursday'): 1,
#          ('bell', 'Thursday', '.'): 1,
#          ('Thursday', '.', 'Netflix'): 1,
#          ('.', 'Netflix', 'last'): 1,
#          ('Netflix', 'last', 'reported'): 1,
#          ('last', 'reported', 'double-digit'): 1,
#          ('reported', 'double-digit', 'user'): 1,
#          ('double-digit', 'user', 'growth'): 1,
#          ('user', 'growth', ','): 1,
#          ('growth', ',', '58'): 1,
#          (',', '58', 'million'): 1,
#          ('58', 'million', 'U.S.'): 1,
#          ('million', 'U.S.', '78'): 1,
#          ('U.S.', '78', 'million'): 1,
#          ('78', 'million', 'international'): 1,
#          ('million', 'international', 'subscribers'): 1,
#          ('international', 'subscribers', '.'): 1,
#          ('subscribers', '.', 'Original'): 1,
#          ('.', 'Original', 'content'): 1,
#          ('Original', 'content', 'aside'): 1,
#          ('content', 'aside', ','): 1,
#          ('aside', ',', 'Netflix'): 1,
#          (',', 'Netflix', 'built'): 1,
#          ('Netflix', 'built', 'large'): 1,
#          ('built', 'large', 'subscriber'): 1,
#          ('large', 'subscriber', 'base'): 1,
#          ('subscriber', 'base', ','): 2,
#          ('base', ',', 'part'): 1,
#          (',', 'part', ','): 1,
#          ('part', ',', 'licensed'): 1,
#          (',', 'licensed', 'content'): 1,
#          ('licensed', 'content', 'number'): 1,
#          ('content', 'number', 'third-party'): 1,
#          ('number', 'third-party', 'TV'): 1,
#          ('third-party', 'TV', 'movie'): 1,
#          ('TV', 'movie', 'studios'): 1,
#          ('movie', 'studios', 'plan'): 1,
#          ('studios', 'plan', 'crowd'): 1,
#          ('plan', 'crowd', 'video'): 1,
#          ('crowd', 'video', 'streaming'): 1,
#          ('video', 'streaming', 'market'): 1,
#          ('streaming', 'market', ','): 1,
#          ('market', ',', 'already'): 1,
#          (',', 'already', 'includes'): 1,
#          ('already', 'includes', 'established'): 1,
#          ('includes', 'established', 'online'): 1,
#          ('established', 'online', 'rivals'): 1,
#          ('online', 'rivals', 'Amazon'): 1,
#          ('rivals', 'Amazon', 'Hulu'): 1,
#          ('Amazon', 'Hulu', '.'): 1,
#          ('Hulu', '.', 'Disney'): 1,
#          ('.', 'Disney', ','): 1,
#          ('Disney', ',', 'agreed'): 1,
#          (',', 'agreed', 'purchase'): 1,
#          ('agreed', 'purchase', 'Twenty-First'): 1,
#          ('purchase', 'Twenty-First', 'Century'): 1,
#          ('Twenty-First', 'Century', 'Fox'): 1,
#          ('Century', 'Fox', 'assets'): 1,
#          ('Fox', 'assets', 'last'): 1,
#          ('assets', 'last', 'summer'): 1,
#          ('last', 'summer', ','): 1,
#          ('summer', ',', 'said'): 1,
#          (',', 'said', 'would'): 1,
#          ('said', 'would', 'pull'): 1,
#          ('would', 'pull', 'movies'): 1,
#          ('pull', 'movies', 'Netflix'): 1,
#          ('movies', 'Netflix', 'launches'): 1,
#          ('Netflix', 'launches', 'Disney+'): 1,
#          ('launches', 'Disney+', 'late'): 1,
#          ('Disney+', 'late', '2019'): 1,
#          ('late', '2019', '.'): 1,
#          ('2019', '.', '&'): 1,
#          ('.', '&', "'s"): 1,
#          ('&', "'s", 'WarnerMedia'): 1,
#          ("'s", 'WarnerMedia', 'announced'): 1,
#          ('WarnerMedia', 'announced', 'October'): 1,
#          ('announced', 'October', 'would'): 1,
#          ('October', 'would', 'release'): 1,
#          ('would', 'release', 'platform'): 1,
#          ('release', 'platform', 'fourth'): 1,
#          ('platform', 'fourth', 'quarter'): 1,
#          ('fourth', 'quarter', '2019'): 1,
#          ('quarter', '2019', '.'): 1,
#          ('2019', '.', 'Apple'): 1,
#          ('.', 'Apple', 'could'): 1,
#          ('Apple', 'could', 'dropping'): 1,
#          ('could', 'dropping', 'service'): 1,
#          ('dropping', 'service', 'year'): 1,
#          ('service', 'year', ','): 1,
#          ('year', ',', 'Comcast'): 1,
#          (',', 'Comcast', "'s"): 1,
#          ('Comcast', "'s", 'NBCUniversal'): 1,
#          ("'s", 'NBCUniversal', 'Monday'): 1,
#          ('NBCUniversal', 'Monday', 'revealed'): 1,
#          ('Monday', 'revealed', 'plans'): 1,
#          ('revealed', 'plans', 'free'): 1,
#          ('plans', 'free', 'streaming'): 1,
#          ('free', 'streaming', 'program'): 1,
#          ('streaming', 'program', 'ads'): 1,
#          ('program', 'ads', 'slated'): 1,
#          ('ads', 'slated', 'early'): 1,
#          ('slated', 'early', '2020'): 1,
#          ('early', '2020', '.'): 1,
#          ('2020', '.', 'New'): 1,
#          ('.', 'New', 'Constructs'): 1,
#          ('Constructs', "'", 'Trainer'): 1,
#          ("'", 'Trainer', 'said'): 1,
#          ('Trainer', 'said', 'Netflix'): 1,
#          ('said', 'Netflix', 'vulnerable'): 1,
#          ('Netflix', 'vulnerable', "'s"): 1,
#          ('vulnerable', "'s", '``'): 1,
#          ("'s", '``', 'one-trick'): 1,
#          ('``', 'one-trick', 'pony'): 1,
#          ('one-trick', 'pony', "''"): 1,
#          ('pony', "''", 'online'): 1,
#          ("''", 'online', 'distribution'): 1,
#          ('online', 'distribution', 'system'): 1,
#          ('distribution', 'system', '``'): 1,
#          ('system', '``', 'defensible'): 1,
#          ('``', 'defensible', '.'): 1,
#          ('defensible', '.', "''"): 1,
#          ('.', "''", 'company'): 1,
#          ("''", 'company', 'keep'): 1,
#          ('company', 'keep', 'growing'): 1,
#          ('keep', 'growing', 'subscriber'): 1,
#          ('growing', 'subscriber', 'base'): 1,
#          ('base', ',', 'need'): 1,
#          (',', 'need', 'address'): 1,
#          ('need', 'address', 'cash'): 1,
#          ('address', 'cash', 'flow'): 1,
#          ('cash', 'flow', ','): 1,
#          ('flow', ',', 'said'): 1,
#          (',', 'said', '.'): 1,
#          ('said', '.', '``'): 1,
#          ('.', '``', 'count'): 1,
#          ('``', 'count', 'one'): 1,
#          ('count', 'one', 'hand'): 1,
#          ('one', 'hand', 'number'): 1,
#          ('hand', 'number', 'firms'): 1,
#          ('number', 'firms', ','): 1,
#          ('firms', ',', 'time'): 1,
#          (',', 'time', ','): 1,
#          ('time', ',', 'successfully'): 1,
#          (',', 'successfully', 'monetized'): 1,
#          ('successfully', 'monetized', 'original'): 1,
#          ('monetized', 'original', 'content'): 1,
#          ('original', 'content', '.'): 1,
#          ('content', '.', "'s"): 1,
#          ('.', "'s", 'expensive'): 1,
#          ("'s", 'expensive', ','): 1,
#          ('expensive', ',', 'difficult'): 1,
#          (',', 'difficult', 'proposition'): 1,
#          ('difficult', 'proposition', ','): 1,
#          ('proposition', ',', "''"): 1,
#          (',', "''", 'argued'): 1,
#          ("''", 'argued', '.'): 1,
#          ('argued', '.', '``'): 1,
#          ('.', '``', 'Disney'): 1,
#          ('``', 'Disney', "'s"): 1,
#          ('Disney', "'s", 'done'): 1,
#          ("'s", 'done', 'part'): 1,
#          ('done', 'part', 'reason'): 1,
#          ('part', 'reason', "'ve"): 1,
#          ('reason', "'ve", 'done'): 1,
#          ("'ve", 'done', '['): 1,
#          ('done', '[', ']'): 1,
#          ('[', ']', "'ve"): 1,
#          (']', "'ve", 'got'): 1,
#          ("'ve", 'got', 'better'): 1,
#          ('got', 'better', 'ways'): 1,
#          ('better', 'ways', 'monetizing'): 1,
#          ('ways', 'monetizing', '.'): 1,
#          ('monetizing', '.', "''"): 1,
#          ('.', "''", '—'): 1,
#          ("''", '—', 'Disclosure'): 1,
#          ('—', 'Disclosure', ':'): 1,
#          ('Disclosure', ':', 'NBCUniversal'): 1,
#          (':', 'NBCUniversal', 'parent'): 1,
#          ('NBCUniversal', 'parent', 'company'): 1,
#          ('parent', 'company', 'CNBC'): 1,
#          ('company', 'CNBC', '.'): 1,
#          ('CNBC', '.', 'TV'): 1,
#          ('.', 'TV', 'WATCH'): 1,
#          ('TV', 'WATCH', 'LIVE'): 2,
#          ('WATCH', 'LIVE', 'WATCH'): 2,
#          ('LIVE', 'WATCH', 'APP'): 2,
#          ('WATCH', 'APP', 'NEXT'): 2,
#          ('APP', 'NEXT', '|'): 2,
#          ('NEXT', '|', 'ET'): 2,
#          ('|', 'ET', 'Listen'): 2,
#          ('ET', 'Listen', 'TV'): 1,
#          ('Listen', 'TV', 'WATCH'): 1,
#          ('ET', 'Listen', 'Subscribe'): 1,
#          ('Listen', 'Subscribe', 'CNBC'): 1,
#          ('Subscribe', 'CNBC', 'PRO'): 1,
#          ('CNBC', 'PRO', 'Licensing'): 1,
#          ('PRO', 'Licensing', '&'): 1,
#          ('Licensing', '&', 'Reprints'): 1,
#          ('&', 'Reprints', 'CNBC'): 1,
#          ('Reprints', 'CNBC', 'Councils'): 1,
#          ('CNBC', 'Councils', 'Supply'): 1,
#          ('Councils', 'Supply', 'Chain'): 1,
#          ('Supply', 'Chain', 'Values'): 1,
#          ('Chain', 'Values', 'CNBC'): 1,
#          ('Values', 'CNBC', 'Peacock'): 1,
#          ('CNBC', 'Peacock', 'Advertise'): 1,
#          ('Peacock', 'Advertise', 'Us'): 1,
#          ('Advertise', 'Us', 'Join'): 1,
#          ('Us', 'Join', 'CNBC'): 1,
#          ('Join', 'CNBC', 'Panel'): 1,
#          ('CNBC', 'Panel', 'Digital'): 1,
#          ('Panel', 'Digital', 'Products'): 1,
#          ('Digital', 'Products', 'News'): 1,
#          ('Products', 'News', 'Releases'): 1,
#          ('News', 'Releases', 'Closed'): 1,
#          ('Releases', 'Closed', 'Captioning'): 1,
#          ('Closed', 'Captioning', 'Corrections'): 1,
#          ('Captioning', 'Corrections', 'CNBC'): 1,
#          ('Corrections', 'CNBC', 'Internships'): 1,
#          ('CNBC', 'Internships', 'Site'): 1,
#          ('Internships', 'Site', 'Map'): 1,
#          ('Site', 'Map', 'Podcasts'): 1,
#          ('Map', 'Podcasts', 'Ad'): 1,
#          ('Podcasts', 'Ad', 'Choices'): 1,
#          ('Ad', 'Choices', 'Careers'): 1,
#          ('Choices', 'Careers', 'Help'): 1,
#          ('Careers', 'Help', 'Contact'): 1,
#          ('Help', 'Contact', 'News'): 1,
#          ('Contact', 'News', 'Tips'): 1,
#          ('News', 'Tips', 'Got'): 1,
#          ('Tips', 'Got', 'confidential'): 1,
#          ('Got', 'confidential', 'news'): 1,
#          ('confidential', 'news', 'tip'): 1,
#          ('news', 'tip', '?'): 1,
#          ('tip', '?', 'want'): 1,
#          ('?', 'want', 'hear'): 1,
#          ('want', 'hear', '.'): 1,
#          ('hear', '.', 'Get'): 1,
#          ('.', 'Get', 'Touch'): 1,
#          ('Get', 'Touch', 'CNBC'): 1,
#          ('Touch', 'CNBC', 'Newsletters'): 1,
#          ('CNBC', 'Newsletters', 'Sign'): 1,
#          ('Newsletters', 'Sign', 'free'): 1,
#          ('Sign', 'free', 'newsletters'): 1,
#          ('free', 'newsletters', 'get'): 1,
#          ('newsletters', 'get', 'CNBC'): 1,
#          ('get', 'CNBC', 'delivered'): 1,
#          ('CNBC', 'delivered', 'inbox'): 1,
#          ('delivered', 'inbox', 'Sign'): 1,
#          ('inbox', 'Sign', 'Get'): 1,
#          ('Sign', 'Get', 'delivered'): 1,
#          ('Get', 'delivered', 'inbox'): 1,
#          ('delivered', 'inbox', ','): 1,
#          ('inbox', ',', 'info'): 1,
#          (',', 'info', 'products'): 1,
#          ('info', 'products', 'services'): 1,
#          ('products', 'services', '.'): 1,
#          ('services', '.', 'Privacy'): 1,
#          ('.', 'Privacy', 'Policy'): 1,
#          ('Privacy', 'Policy', '|'): 1,
#          ('Policy', '|', 'Sell'): 1,
#          ('|', 'Sell', 'Personal'): 1,
#          ('Sell', 'Personal', 'Information'): 1,
#          ('Personal', 'Information', '|'): 1,
#          ('Information', '|', 'CA'): 1,
#          ('|', 'CA', 'Notice'): 1,
#          ('CA', 'Notice', '|'): 1,
#          ('Notice', '|', 'Terms'): 1,
#          ('|', 'Terms', 'Service'): 1,
#          ('Terms', 'Service', '©'): 1,
#          ('Service', '©', '2021'): 1,
#          ('©', '2021', 'CNBC'): 1,
#          ('2021', 'CNBC', 'LLC'): 1,
#          ('CNBC', 'LLC', '.'): 1,
#          ('LLC', '.', 'Rights'): 1,
#          ('.', 'Rights', 'Reserved'): 1,
#          ('Rights', 'Reserved', '.'): 1,
#          ('Reserved', '.', 'Division'): 1,
#          ('.', 'Division', 'NBCUniversal'): 1,
#          ('Division', 'NBCUniversal', 'Data'): 1,
#          ('NBCUniversal', 'Data', 'real-time'): 1,
#          ('Data', 'real-time', 'snapshot'): 1,
#          ('real-time', 'snapshot', '*'): 1,
#          ('snapshot', '*', 'Data'): 1,
#          ('*', 'Data', 'delayed'): 1,
#          ('Data', 'delayed', 'least'): 1,
#          ('delayed', 'least', '15'): 1,
#          ('least', '15', 'minutes'): 1,
#          ('15', 'minutes', '.'): 1,
#          ('minutes', '.', 'Global'): 1,
#          ('.', 'Global', 'Business'): 1,
#          ('Global', 'Business', 'Financial'): 1,
#          ('Business', 'Financial', 'News'): 1,
#          ('Financial', 'News', ','): 1,
#          ('News', ',', 'Stock'): 1,
#          (',', 'Stock', 'Quotes'): 1,
#          ('Stock', 'Quotes', ','): 1,
#          ('Quotes', ',', 'Market'): 1,
#          (',', 'Market', 'Data'): 1,
#          ('Market', 'Data', 'Analysis'): 1,
#          ('Data', 'Analysis', '.'): 1,
#          ('Analysis', '.', 'Market'): 1,
#          ('.', 'Market', 'Data'): 1,
#          ('Market', 'Data', 'Terms'): 1,
#          ('Data', 'Terms', 'Use'): 1,
#          ('Terms', 'Use', 'Disclaimers'): 1,
#          ('Use', 'Disclaimers', 'Data'): 1,
#          ('Disclaimers', 'Data', 'also'): 1,
#          ('Data', 'also', 'provided'): 1})

# %% [markdown]
# ### 4d. Print bigrams and trigrams in the first 5 sentences

# %%
for i, sentence in enumerate(sentences[:5]):
    
    tokens = word_tokenize(sentence)
    print(f"============================ SENTENCE {i+1} BIGRAM ============================\n")
    pprint(Counter(ngrams(tokens, 2)))
    print(f"============================ SENTENCE {i+1} TRIGRAM ============================\n")
    pprint(Counter(ngrams(tokens, 3)))
    print('\n\n\n')
# Out:
# ============================ SENTENCE 1 BIGRAM ============================
#
# Counter({('TV', 'Live'): 4,
#          ('Live', 'TV'): 4,
#          ('Share', 'Article'): 4,
#          ('Article', 'via'): 4,
#          ('Markets', 'Pre-Markets'): 2,
#          ('Pre-Markets', 'U.S.'): 2,
#          ('U.S.', 'Markets'): 2,
#          ('Markets', 'Currencies'): 2,
#          ('Currencies', 'Cryptocurrency'): 2,
#          ('Cryptocurrency', 'Futures'): 2,
#          ('Futures', '&'): 2,
#          ('&', 'Commodities'): 2,
#          ('Commodities', 'Bonds'): 2,
#          ('Bonds', 'Funds'): 2,
#          ('Funds', '&'): 2,
#          ('&', 'ETFs'): 2,
#          ('ETFs', 'Business'): 2,
#          ('Business', 'Economy'): 2,
#          ('Economy', 'Finance'): 2,
#          ('Finance', 'Health'): 2,
#          ('Health', '&'): 2,
#          ('&', 'Science'): 2,
#          ('Science', 'Media'): 2,
#          ('Media', 'Real'): 2,
#          ('Real', 'Estate'): 2,
#          ('Estate', 'Energy'): 2,
#          ('Energy', 'Climate'): 2,
#          ('Climate', 'Transportation'): 2,
#          ('Transportation', 'Industrials'): 2,
#          ('Industrials', 'Retail'): 2,
#          ('Retail', 'Wealth'): 2,
#          ('Wealth', 'Life'): 2,
#          ('Life', 'Small'): 2,
#          ('Small', 'Business'): 2,
#          ('Business', 'Investing'): 2,
#          ('Investing', 'Invest'): 2,
#          ('Invest', 'In'): 2,
#          ('In', 'You'): 2,
#          ('You', 'Personal'): 2,
#          ('Personal', 'Finance'): 2,
#          ('Finance', 'Fintech'): 2,
#          ('Fintech', 'Financial'): 2,
#          ('Financial', 'Advisors'): 2,
#          ('Advisors', 'Trading'): 2,
#          ('Trading', 'Nation'): 2,
#          ('Nation', 'Options'): 2,
#          ('Options', 'Action'): 2,
#          ('Action', 'ETF'): 2,
#          ('ETF', 'Street'): 2,
#          ('Street', 'Buffett'): 2,
#          ('Buffett', 'Archive'): 2,
#          ('Archive', 'Earnings'): 2,
#          ('Earnings', 'Trader'): 2,
#          ('Trader', 'Talk'): 2,
#          ('Talk', 'Tech'): 2,
#          ('Tech', 'Cybersecurity'): 2,
#          ('Cybersecurity', 'Enterprise'): 2,
#          ('Enterprise', 'Internet'): 2,
#          ('Internet', 'Media'): 2,
#          ('Media', 'Mobile'): 2,
#          ('Mobile', 'Social'): 2,
#          ('Social', 'Media'): 2,
#          ('Media', 'CNBC'): 2,
#          ('CNBC', 'Disruptor'): 2,
#          ('Disruptor', '50'): 2,
#          ('50', 'Tech'): 2,
#          ('Tech', 'Guide'): 2,
#          ('Guide', 'Politics'): 2,
#          ('Politics', 'White'): 2,
#          ('White', 'House'): 2,
#          ('House', 'Policy'): 2,
#          ('Policy', 'Defense'): 2,
#          ('Defense', 'Congress'): 2,
#          ('Congress', 'Equity'): 2,
#          ('Equity', 'and'): 2,
#          ('and', 'Opportunity'): 2,
#          ('Opportunity', 'CNBC'): 2,
#          ('CNBC', 'TV'): 2,
#          ('Live', 'Audio'): 2,
#          ('Audio', 'Business'): 2,
#          ('Business', 'Day'): 2,
#          ('Day', 'Shows'): 2,
#          ('Shows', 'The'): 2,
#          ('The', 'News'): 2,
#          ('News', 'with'): 2,
#          ('with', 'Shepard'): 2,
#          ('Shepard', 'Smith'): 2,
#          ('Smith', 'Entertainment'): 2,
#          ('Entertainment', 'Shows'): 2,
#          ('Shows', 'Full'): 2,
#          ('Full', 'Episodes'): 2,
#          ('Episodes', 'Latest'): 2,
#          ('Latest', 'Video'): 2,
#          ('Video', 'Top'): 2,
#          ('Top', 'Video'): 2,
#          ('Video', 'CEO'): 2,
#          ('CEO', 'Interviews'): 2,
#          ('Interviews', 'CNBC'): 2,
#          ('CNBC', 'Documentaries'): 2,
#          ('Documentaries', 'CNBC'): 2,
#          ('CNBC', 'Podcasts'): 2,
#          ('Podcasts', 'CNBC'): 2,
#          ('CNBC', 'World'): 2,
#          ('World', 'Digital'): 2,
#          ('Digital', 'Originals'): 2,
#          ('Originals', 'Live'): 2,
#          ('TV', 'Schedule'): 2,
#          ('Schedule', 'Watchlist'): 2,
#          ('Watchlist', 'PRO'): 2,
#          ('PRO', 'Pro'): 2,
#          ('Pro', 'News'): 2,
#          ('News', 'Pro'): 2,
#          ('Pro', 'Live'): 2,
#          ('Live', 'Subscribe'): 2,
#          ('Subscribe', 'Sign'): 2,
#          ('Sign', 'In'): 2,
#          ('In', 'Menu'): 2,
#          ('price', 'hike'): 2,
#          ('hike', 'is'): 2,
#          ('is', 'a'): 2,
#          ('Thu', ','): 2,
#          (',', 'Jan'): 2,
#          ('Jan', '17'): 2,
#          ('17', '2019'): 2,
#          ('PM', 'EST'): 2,
#          ('Skip', 'Navigation'): 1,
#          ('Navigation', 'Markets'): 1,
#          ('Menu', 'Make'): 1,
#          ('Make', 'It'): 1,
#          ('It', 'USA'): 1,
#          ('USA', 'INTL'): 1,
#          ('INTL', 'watch'): 1,
#          ('watch', 'live'): 1,
#          ('live', 'Search'): 1,
#          ('Search', 'quotes'): 1,
#          ('quotes', ','): 1,
#          (',', 'news'): 1,
#          ('news', '&'): 1,
#          ('&', 'videos'): 1,
#          ('videos', 'SIGN'): 1,
#          ('SIGN', 'IN'): 1,
#          ('IN', 'Markets'): 1,
#          ('Menu', 'Tech'): 1,
#          ('Tech', 'Netflix'): 1,
#          ('Netflix', "'s"): 1,
#          ("'s", 'price'): 1,
#          ('a', "'Catch-22"): 1,
#          ("'Catch-22", "'"): 1,
#          ("'", 'that'): 1,
#          ('that', 'actually'): 1,
#          ('actually', 'helps'): 1,
#          ('helps', 'Disney'): 1,
#          ('Disney', "'s"): 1,
#          ("'s", 'upcoming'): 1,
#          ('upcoming', 'streaming'): 1,
#          ('streaming', 'service'): 1,
#          ('service', 'Published'): 1,
#          ('Published', 'Thu'): 1,
#          ('2019', '1:04'): 1,
#          ('1:04', 'PM'): 1,
#          ('EST', 'Updated'): 1,
#          ('Updated', 'Thu'): 1,
#          ('2019', '1:42'): 1,
#          ('1:42', 'PM'): 1,
#          ('EST', 'Tyler'): 1,
#          ('Tyler', 'Clifford'): 1,
#          ('Clifford', '@'): 1,
#          ('@', '_TylerTheTyler_'): 1,
#          ('_TylerTheTyler_', 'Share'): 1,
#          ('Share', 'Share'): 1,
#          ('via', 'Facebook'): 1,
#          ('Facebook', 'Share'): 1,
#          ('via', 'Twitter'): 1,
#          ('Twitter', 'Share'): 1,
#          ('via', 'LinkedIn'): 1,
#          ('LinkedIn', 'Share'): 1,
#          ('via', 'Email'): 1,
#          ('Email', 'Key'): 1,
#          ('Key', 'Points'): 1,
#          ('Points', 'Netflix'): 1,
#          ('Netflix', 'subscription'): 1,
#          ('subscription', 'price'): 1,
#          ('a', '``'): 1,
#          ('``', 'key'): 1,
#          ('key', 'dilemma'): 1,
#          ('dilemma', "''"): 1,
#          ("''", 'that'): 1,
#          ('that', 'makes'): 1,
#          ('makes', 'future'): 1,
#          ('future', 'competitors'): 1,
#          ('competitors', 'like'): 1,
#          ('like', 'Disney'): 1,
#          ('Disney', 'more'): 1,
#          ('more', 'viable'): 1,
#          ('viable', ','): 1,
#          (',', 'New'): 1,
#          ('New', 'Constructs'): 1,
#          ('Constructs', 'CEO'): 1,
#          ('CEO', 'David'): 1,
#          ('David', 'Trainer'): 1,
#          ('Trainer', 'says'): 1,
#          ('says', '.'): 1})
# ============================ SENTENCE 1 TRIGRAM ============================
#
# Counter({('Share', 'Article', 'via'): 4,
#          ('Markets', 'Pre-Markets', 'U.S.'): 2,
#          ('Pre-Markets', 'U.S.', 'Markets'): 2,
#          ('U.S.', 'Markets', 'Currencies'): 2,
#          ('Markets', 'Currencies', 'Cryptocurrency'): 2,
#          ('Currencies', 'Cryptocurrency', 'Futures'): 2,
#          ('Cryptocurrency', 'Futures', '&'): 2,
#          ('Futures', '&', 'Commodities'): 2,
#          ('&', 'Commodities', 'Bonds'): 2,
#          ('Commodities', 'Bonds', 'Funds'): 2,
#          ('Bonds', 'Funds', '&'): 2,
#          ('Funds', '&', 'ETFs'): 2,
#          ('&', 'ETFs', 'Business'): 2,
#          ('ETFs', 'Business', 'Economy'): 2,
#          ('Business', 'Economy', 'Finance'): 2,
#          ('Economy', 'Finance', 'Health'): 2,
#          ('Finance', 'Health', '&'): 2,
#          ('Health', '&', 'Science'): 2,
#          ('&', 'Science', 'Media'): 2,
#          ('Science', 'Media', 'Real'): 2,
#          ('Media', 'Real', 'Estate'): 2,
#          ('Real', 'Estate', 'Energy'): 2,
#          ('Estate', 'Energy', 'Climate'): 2,
#          ('Energy', 'Climate', 'Transportation'): 2,
#          ('Climate', 'Transportation', 'Industrials'): 2,
#          ('Transportation', 'Industrials', 'Retail'): 2,
#          ('Industrials', 'Retail', 'Wealth'): 2,
#          ('Retail', 'Wealth', 'Life'): 2,
#          ('Wealth', 'Life', 'Small'): 2,
#          ('Life', 'Small', 'Business'): 2,
#          ('Small', 'Business', 'Investing'): 2,
#          ('Business', 'Investing', 'Invest'): 2,
#          ('Investing', 'Invest', 'In'): 2,
#          ('Invest', 'In', 'You'): 2,
#          ('In', 'You', 'Personal'): 2,
#          ('You', 'Personal', 'Finance'): 2,
#          ('Personal', 'Finance', 'Fintech'): 2,
#          ('Finance', 'Fintech', 'Financial'): 2,
#          ('Fintech', 'Financial', 'Advisors'): 2,
#          ('Financial', 'Advisors', 'Trading'): 2,
#          ('Advisors', 'Trading', 'Nation'): 2,
#          ('Trading', 'Nation', 'Options'): 2,
#          ('Nation', 'Options', 'Action'): 2,
#          ('Options', 'Action', 'ETF'): 2,
#          ('Action', 'ETF', 'Street'): 2,
#          ('ETF', 'Street', 'Buffett'): 2,
#          ('Street', 'Buffett', 'Archive'): 2,
#          ('Buffett', 'Archive', 'Earnings'): 2,
#          ('Archive', 'Earnings', 'Trader'): 2,
#          ('Earnings', 'Trader', 'Talk'): 2,
#          ('Trader', 'Talk', 'Tech'): 2,
#          ('Talk', 'Tech', 'Cybersecurity'): 2,
#          ('Tech', 'Cybersecurity', 'Enterprise'): 2,
#          ('Cybersecurity', 'Enterprise', 'Internet'): 2,
#          ('Enterprise', 'Internet', 'Media'): 2,
#          ('Internet', 'Media', 'Mobile'): 2,
#          ('Media', 'Mobile', 'Social'): 2,
#          ('Mobile', 'Social', 'Media'): 2,
#          ('Social', 'Media', 'CNBC'): 2,
#          ('Media', 'CNBC', 'Disruptor'): 2,
#          ('CNBC', 'Disruptor', '50'): 2,
#          ('Disruptor', '50', 'Tech'): 2,
#          ('50', 'Tech', 'Guide'): 2,
#          ('Tech', 'Guide', 'Politics'): 2,
#          ('Guide', 'Politics', 'White'): 2,
#          ('Politics', 'White', 'House'): 2,
#          ('White', 'House', 'Policy'): 2,
#          ('House', 'Policy', 'Defense'): 2,
#          ('Policy', 'Defense', 'Congress'): 2,
#          ('Defense', 'Congress', 'Equity'): 2,
#          ('Congress', 'Equity', 'and'): 2,
#          ('Equity', 'and', 'Opportunity'): 2,
#          ('and', 'Opportunity', 'CNBC'): 2,
#          ('Opportunity', 'CNBC', 'TV'): 2,
#          ('CNBC', 'TV', 'Live'): 2,
#          ('TV', 'Live', 'TV'): 2,
#          ('Live', 'TV', 'Live'): 2,
#          ('TV', 'Live', 'Audio'): 2,
#          ('Live', 'Audio', 'Business'): 2,
#          ('Audio', 'Business', 'Day'): 2,
#          ('Business', 'Day', 'Shows'): 2,
#          ('Day', 'Shows', 'The'): 2,
#          ('Shows', 'The', 'News'): 2,
#          ('The', 'News', 'with'): 2,
#          ('News', 'with', 'Shepard'): 2,
#          ('with', 'Shepard', 'Smith'): 2,
#          ('Shepard', 'Smith', 'Entertainment'): 2,
#          ('Smith', 'Entertainment', 'Shows'): 2,
#          ('Entertainment', 'Shows', 'Full'): 2,
#          ('Shows', 'Full', 'Episodes'): 2,
#          ('Full', 'Episodes', 'Latest'): 2,
#          ('Episodes', 'Latest', 'Video'): 2,
#          ('Latest', 'Video', 'Top'): 2,
#          ('Video', 'Top', 'Video'): 2,
#          ('Top', 'Video', 'CEO'): 2,
#          ('Video', 'CEO', 'Interviews'): 2,
#          ('CEO', 'Interviews', 'CNBC'): 2,
#          ('Interviews', 'CNBC', 'Documentaries'): 2,
#          ('CNBC', 'Documentaries', 'CNBC'): 2,
#          ('Documentaries', 'CNBC', 'Podcasts'): 2,
#          ('CNBC', 'Podcasts', 'CNBC'): 2,
#          ('Podcasts', 'CNBC', 'World'): 2,
#          ('CNBC', 'World', 'Digital'): 2,
#          ('World', 'Digital', 'Originals'): 2,
#          ('Digital', 'Originals', 'Live'): 2,
#          ('Originals', 'Live', 'TV'): 2,
#          ('Live', 'TV', 'Schedule'): 2,
#          ('TV', 'Schedule', 'Watchlist'): 2,
#          ('Schedule', 'Watchlist', 'PRO'): 2,
#          ('Watchlist', 'PRO', 'Pro'): 2,
#          ('PRO', 'Pro', 'News'): 2,
#          ('Pro', 'News', 'Pro'): 2,
#          ('News', 'Pro', 'Live'): 2,
#          ('Pro', 'Live', 'Subscribe'): 2,
#          ('Live', 'Subscribe', 'Sign'): 2,
#          ('Subscribe', 'Sign', 'In'): 2,
#          ('Sign', 'In', 'Menu'): 2,
#          ('price', 'hike', 'is'): 2,
#          ('hike', 'is', 'a'): 2,
#          ('Thu', ',', 'Jan'): 2,
#          (',', 'Jan', '17'): 2,
#          ('Jan', '17', '2019'): 2,
#          ('Skip', 'Navigation', 'Markets'): 1,
#          ('Navigation', 'Markets', 'Pre-Markets'): 1,
#          ('In', 'Menu', 'Make'): 1,
#          ('Menu', 'Make', 'It'): 1,
#          ('Make', 'It', 'USA'): 1,
#          ('It', 'USA', 'INTL'): 1,
#          ('USA', 'INTL', 'watch'): 1,
#          ('INTL', 'watch', 'live'): 1,
#          ('watch', 'live', 'Search'): 1,
#          ('live', 'Search', 'quotes'): 1,
#          ('Search', 'quotes', ','): 1,
#          ('quotes', ',', 'news'): 1,
#          (',', 'news', '&'): 1,
#          ('news', '&', 'videos'): 1,
#          ('&', 'videos', 'SIGN'): 1,
#          ('videos', 'SIGN', 'IN'): 1,
#          ('SIGN', 'IN', 'Markets'): 1,
#          ('IN', 'Markets', 'Pre-Markets'): 1,
#          ('In', 'Menu', 'Tech'): 1,
#          ('Menu', 'Tech', 'Netflix'): 1,
#          ('Tech', 'Netflix', "'s"): 1,
#          ('Netflix', "'s", 'price'): 1,
#          ("'s", 'price', 'hike'): 1,
#          ('is', 'a', "'Catch-22"): 1,
#          ('a', "'Catch-22", "'"): 1,
#          ("'Catch-22", "'", 'that'): 1,
#          ("'", 'that', 'actually'): 1,
#          ('that', 'actually', 'helps'): 1,
#          ('actually', 'helps', 'Disney'): 1,
#          ('helps', 'Disney', "'s"): 1,
#          ('Disney', "'s", 'upcoming'): 1,
#          ("'s", 'upcoming', 'streaming'): 1,
#          ('upcoming', 'streaming', 'service'): 1,
#          ('streaming', 'service', 'Published'): 1,
#          ('service', 'Published', 'Thu'): 1,
#          ('Published', 'Thu', ','): 1,
#          ('17', '2019', '1:04'): 1,
#          ('2019', '1:04', 'PM'): 1,
#          ('1:04', 'PM', 'EST'): 1,
#          ('PM', 'EST', 'Updated'): 1,
#          ('EST', 'Updated', 'Thu'): 1,
#          ('Updated', 'Thu', ','): 1,
#          ('17', '2019', '1:42'): 1,
#          ('2019', '1:42', 'PM'): 1,
#          ('1:42', 'PM', 'EST'): 1,
#          ('PM', 'EST', 'Tyler'): 1,
#          ('EST', 'Tyler', 'Clifford'): 1,
#          ('Tyler', 'Clifford', '@'): 1,
#          ('Clifford', '@', '_TylerTheTyler_'): 1,
#          ('@', '_TylerTheTyler_', 'Share'): 1,
#          ('_TylerTheTyler_', 'Share', 'Share'): 1,
#          ('Share', 'Share', 'Article'): 1,
#          ('Article', 'via', 'Facebook'): 1,
#          ('via', 'Facebook', 'Share'): 1,
#          ('Facebook', 'Share', 'Article'): 1,
#          ('Article', 'via', 'Twitter'): 1,
#          ('via', 'Twitter', 'Share'): 1,
#          ('Twitter', 'Share', 'Article'): 1,
#          ('Article', 'via', 'LinkedIn'): 1,
#          ('via', 'LinkedIn', 'Share'): 1,
#          ('LinkedIn', 'Share', 'Article'): 1,
#          ('Article', 'via', 'Email'): 1,
#          ('via', 'Email', 'Key'): 1,
#          ('Email', 'Key', 'Points'): 1,
#          ('Key', 'Points', 'Netflix'): 1,
#          ('Points', 'Netflix', 'subscription'): 1,
#          ('Netflix', 'subscription', 'price'): 1,
#          ('subscription', 'price', 'hike'): 1,
#          ('is', 'a', '``'): 1,
#          ('a', '``', 'key'): 1,
#          ('``', 'key', 'dilemma'): 1,
#          ('key', 'dilemma', "''"): 1,
#          ('dilemma', "''", 'that'): 1,
#          ("''", 'that', 'makes'): 1,
#          ('that', 'makes', 'future'): 1,
#          ('makes', 'future', 'competitors'): 1,
#          ('future', 'competitors', 'like'): 1,
#          ('competitors', 'like', 'Disney'): 1,
#          ('like', 'Disney', 'more'): 1,
#          ('Disney', 'more', 'viable'): 1,
#          ('more', 'viable', ','): 1,
#          ('viable', ',', 'New'): 1,
#          (',', 'New', 'Constructs'): 1,
#          ('New', 'Constructs', 'CEO'): 1,
#          ('Constructs', 'CEO', 'David'): 1,
#          ('CEO', 'David', 'Trainer'): 1,
#          ('David', 'Trainer', 'says'): 1,
#          ('Trainer', 'says', '.'): 1})
#
#
#
#
# ============================ SENTENCE 2 BIGRAM ============================
#
# Counter({('However', ','): 1,
#          (',', 'Aegis'): 1,
#          ('Aegis', 'Capital'): 1,
#          ('Capital', "'s"): 1,
#          ("'s", 'Victory'): 1,
#          ('Victory', 'Anthony'): 1,
#          ('Anthony', 'sees'): 1,
#          ('sees', 'the'): 1,
#          ('the', 'Netflix'): 1,
#          ('Netflix', 'price'): 1,
#          ('price', 'increase'): 1,
#          ('increase', 'as'): 1,
#          ('as', 'extra'): 1,
#          ('extra', 'money'): 1,
#          ('money', 'to'): 1,
#          ('to', 'invest'): 1,
#          ('invest', 'in'): 1,
#          ('in', 'more'): 1,
#          ('more', 'original'): 1,
#          ('original', 'content'): 1,
#          ('content', 'or'): 1,
#          ('or', 'pad'): 1,
#          ('pad', 'the'): 1,
#          ('the', 'bottom'): 1,
#          ('bottom', 'line'): 1,
#          ('line', '.'): 1})
# ============================ SENTENCE 2 TRIGRAM ============================
#
# Counter({('However', ',', 'Aegis'): 1,
#          (',', 'Aegis', 'Capital'): 1,
#          ('Aegis', 'Capital', "'s"): 1,
#          ('Capital', "'s", 'Victory'): 1,
#          ("'s", 'Victory', 'Anthony'): 1,
#          ('Victory', 'Anthony', 'sees'): 1,
#          ('Anthony', 'sees', 'the'): 1,
#          ('sees', 'the', 'Netflix'): 1,
#          ('the', 'Netflix', 'price'): 1,
#          ('Netflix', 'price', 'increase'): 1,
#          ('price', 'increase', 'as'): 1,
#          ('increase', 'as', 'extra'): 1,
#          ('as', 'extra', 'money'): 1,
#          ('extra', 'money', 'to'): 1,
#          ('money', 'to', 'invest'): 1,
#          ('to', 'invest', 'in'): 1,
#          ('invest', 'in', 'more'): 1,
#          ('in', 'more', 'original'): 1,
#          ('more', 'original', 'content'): 1,
#          ('original', 'content', 'or'): 1,
#          ('content', 'or', 'pad'): 1,
#          ('or', 'pad', 'the'): 1,
#          ('pad', 'the', 'bottom'): 1,
#          ('the', 'bottom', 'line'): 1,
#          ('bottom', 'line', '.'): 1})
#
#
#
#
# ============================ SENTENCE 3 BIGRAM ============================
#
# Counter({('David', 'Trainer'): 2,
#          ('VIDEO', '6:10'): 1,
#          ('6:10', '06:10'): 1,
#          ('06:10', 'Netflix'): 1,
#          ('Netflix', "'s"): 1,
#          ("'s", 'decision'): 1,
#          ('decision', 'to'): 1,
#          ('to', 'raise'): 1,
#          ('raise', 'prices'): 1,
#          ('prices', 'is'): 1,
#          ('is', 'a'): 1,
#          ('a', 'Catch-22'): 1,
#          ('Catch-22', ','): 1,
#          (',', 'says'): 1,
#          ('says', 'New'): 1,
#          ('New', 'Constructs'): 1,
#          ('Constructs', "'"): 1,
#          ("'", 'David'): 1,
#          ('Trainer', 'Closing'): 1,
#          ('Closing', 'Bell'): 1,
#          ('Bell', 'Disney'): 1,
#          ('Disney', 'will'): 1,
#          ('will', 'have'): 1,
#          ('have', 'a'): 1,
#          ('a', 'competitive'): 1,
#          ('competitive', 'advantage'): 1,
#          ('advantage', 'over'): 1,
#          ('over', 'Netflix'): 1,
#          ('Netflix', 'when'): 1,
#          ('when', 'the'): 1,
#          ('the', 'entertainment'): 1,
#          ('entertainment', 'conglomerate'): 1,
#          ('conglomerate', 'launches'): 1,
#          ('launches', 'a'): 1,
#          ('a', 'competing'): 1,
#          ('competing', 'video'): 1,
#          ('video', 'streaming'): 1,
#          ('streaming', 'platform'): 1,
#          ('platform', 'later'): 1,
#          ('later', 'this'): 1,
#          ('this', 'year'): 1,
#          ('year', ','): 1,
#          (',', 'according'): 1,
#          ('according', 'to'): 1,
#          ('to', 'Wall'): 1,
#          ('Wall', 'Street'): 1,
#          ('Street', 'analyst'): 1,
#          ('analyst', 'David'): 1,
#          ('Trainer', '.'): 1})
# ============================ SENTENCE 3 TRIGRAM ============================
#
# Counter({('VIDEO', '6:10', '06:10'): 1,
#          ('6:10', '06:10', 'Netflix'): 1,
#          ('06:10', 'Netflix', "'s"): 1,
#          ('Netflix', "'s", 'decision'): 1,
#          ("'s", 'decision', 'to'): 1,
#          ('decision', 'to', 'raise'): 1,
#          ('to', 'raise', 'prices'): 1,
#          ('raise', 'prices', 'is'): 1,
#          ('prices', 'is', 'a'): 1,
#          ('is', 'a', 'Catch-22'): 1,
#          ('a', 'Catch-22', ','): 1,
#          ('Catch-22', ',', 'says'): 1,
#          (',', 'says', 'New'): 1,
#          ('says', 'New', 'Constructs'): 1,
#          ('New', 'Constructs', "'"): 1,
#          ('Constructs', "'", 'David'): 1,
#          ("'", 'David', 'Trainer'): 1,
#          ('David', 'Trainer', 'Closing'): 1,
#          ('Trainer', 'Closing', 'Bell'): 1,
#          ('Closing', 'Bell', 'Disney'): 1,
#          ('Bell', 'Disney', 'will'): 1,
#          ('Disney', 'will', 'have'): 1,
#          ('will', 'have', 'a'): 1,
#          ('have', 'a', 'competitive'): 1,
#          ('a', 'competitive', 'advantage'): 1,
#          ('competitive', 'advantage', 'over'): 1,
#          ('advantage', 'over', 'Netflix'): 1,
#          ('over', 'Netflix', 'when'): 1,
#          ('Netflix', 'when', 'the'): 1,
#          ('when', 'the', 'entertainment'): 1,
#          ('the', 'entertainment', 'conglomerate'): 1,
#          ('entertainment', 'conglomerate', 'launches'): 1,
#          ('conglomerate', 'launches', 'a'): 1,
#          ('launches', 'a', 'competing'): 1,
#          ('a', 'competing', 'video'): 1,
#          ('competing', 'video', 'streaming'): 1,
#          ('video', 'streaming', 'platform'): 1,
#          ('streaming', 'platform', 'later'): 1,
#          ('platform', 'later', 'this'): 1,
#          ('later', 'this', 'year'): 1,
#          ('this', 'year', ','): 1,
#          ('year', ',', 'according'): 1,
#          (',', 'according', 'to'): 1,
#          ('according', 'to', 'Wall'): 1,
#          ('to', 'Wall', 'Street'): 1,
#          ('Wall', 'Street', 'analyst'): 1,
#          ('Street', 'analyst', 'David'): 1,
#          ('analyst', 'David', 'Trainer'): 1,
#          ('David', 'Trainer', '.'): 1})
#
#
#
#
# ============================ SENTENCE 4 BIGRAM ============================
#
# Counter({('``', '['): 1,
#          ('[', 'Disney'): 1,
#          ('Disney', "'s"): 1,
#          ("'s", ']'): 1,
#          (']', 'got'): 1,
#          ('got', 'the'): 1,
#          ('the', 'ability'): 1,
#          ('ability', 'to'): 1,
#          ('to', 'merchandise'): 1,
#          ('merchandise', ','): 1,
#          (',', 'which'): 1,
#          ('which', 'is'): 1,
#          ('is', 'another'): 1,
#          ('another', 'way'): 1,
#          ('way', 'to'): 1,
#          ('to', 'monetize'): 1,
#          ('monetize', 'content'): 1,
#          ('content', 'in'): 1,
#          ('in', 'a'): 1,
#          ('a', 'way'): 1,
#          ('way', 'that'): 1,
#          ('that', 'Netflix'): 1,
#          ('Netflix', 'does'): 1,
#          ('does', 'not'): 1,
#          ('not', 'have'): 1,
#          ('have', ','): 1,
#          (',', "''"): 1,
#          ("''", 'Trainer'): 1,
#          ('Trainer', 'said'): 1,
#          ('said', 'on'): 1,
#          ('on', 'CNBC'): 1,
#          ('CNBC', "'s"): 1,
#          ("'s", '``'): 1,
#          ('``', 'Closing'): 1,
#          ('Closing', 'Bell'): 1,
#          ('Bell', "''"): 1,
#          ("''", 'Wednesday'): 1,
#          ('Wednesday', '.'): 1})
# ============================ SENTENCE 4 TRIGRAM ============================
#
# Counter({('``', '[', 'Disney'): 1,
#          ('[', 'Disney', "'s"): 1,
#          ('Disney', "'s", ']'): 1,
#          ("'s", ']', 'got'): 1,
#          (']', 'got', 'the'): 1,
#          ('got', 'the', 'ability'): 1,
#          ('the', 'ability', 'to'): 1,
#          ('ability', 'to', 'merchandise'): 1,
#          ('to', 'merchandise', ','): 1,
#          ('merchandise', ',', 'which'): 1,
#          (',', 'which', 'is'): 1,
#          ('which', 'is', 'another'): 1,
#          ('is', 'another', 'way'): 1,
#          ('another', 'way', 'to'): 1,
#          ('way', 'to', 'monetize'): 1,
#          ('to', 'monetize', 'content'): 1,
#          ('monetize', 'content', 'in'): 1,
#          ('content', 'in', 'a'): 1,
#          ('in', 'a', 'way'): 1,
#          ('a', 'way', 'that'): 1,
#          ('way', 'that', 'Netflix'): 1,
#          ('that', 'Netflix', 'does'): 1,
#          ('Netflix', 'does', 'not'): 1,
#          ('does', 'not', 'have'): 1,
#          ('not', 'have', ','): 1,
#          ('have', ',', "''"): 1,
#          (',', "''", 'Trainer'): 1,
#          ("''", 'Trainer', 'said'): 1,
#          ('Trainer', 'said', 'on'): 1,
#          ('said', 'on', 'CNBC'): 1,
#          ('on', 'CNBC', "'s"): 1,
#          ('CNBC', "'s", '``'): 1,
#          ("'s", '``', 'Closing'): 1,
#          ('``', 'Closing', 'Bell'): 1,
#          ('Closing', 'Bell', "''"): 1,
#          ('Bell', "''", 'Wednesday'): 1,
#          ("''", 'Wednesday', '.'): 1})
#
#
#
#
# ============================ SENTENCE 5 BIGRAM ============================
#
# Counter({('He', "'s"): 1,
#          ("'s", 'chief'): 1,
#          ('chief', 'of'): 1,
#          ('of', 'the'): 1,
#          ('the', 'New'): 1,
#          ('New', 'Constructs'): 1,
#          ('Constructs', 'research'): 1,
#          ('research', 'firm'): 1,
#          ('firm', '.'): 1})
# ============================ SENTENCE 5 TRIGRAM ============================
#
# Counter({('He', "'s", 'chief'): 1,
#          ("'s", 'chief', 'of'): 1,
#          ('chief', 'of', 'the'): 1,
#          ('of', 'the', 'New'): 1,
#          ('the', 'New', 'Constructs'): 1,
#          ('New', 'Constructs', 'research'): 1,
#          ('Constructs', 'research', 'firm'): 1,
#          ('research', 'firm', '.'): 1})

# %% [markdown]
# ### 4e. Print POS tags in the first 5 sentences

# %%
for i, sentence in enumerate(sentences[:5]):
    
    tokens = word_tokenize(sentence)
    sentence_pos = pos_tag(tokens)
    print(f"============================ SENTENCE {i+1} POS TAGS ============================\n")
#     print(sentence)
    pprint(sentence_pos)

    print('\n\n\n')
# Out:
# ============================ SENTENCE 1 POS TAGS ============================
#
# [('Skip', 'JJ'),
#  ('Navigation', 'NNP'),
#  ('Markets', 'NNP'),
#  ('Pre-Markets', 'NNP'),
#  ('U.S.', 'NNP'),
#  ('Markets', 'NNP'),
#  ('Currencies', 'NNP'),
#  ('Cryptocurrency', 'NNP'),
#  ('Futures', 'NNP'),
#  ('&', 'CC'),
#  ('Commodities', 'NNP'),
#  ('Bonds', 'NNP'),
#  ('Funds', 'NNP'),
#  ('&', 'CC'),
#  ('ETFs', 'NNP'),
#  ('Business', 'NNP'),
#  ('Economy', 'NNP'),
#  ('Finance', 'NNP'),
#  ('Health', 'NNP'),
#  ('&', 'CC'),
#  ('Science', 'NNP'),
#  ('Media', 'NNP'),
#  ('Real', 'NNP'),
#  ('Estate', 'NNP'),
#  ('Energy', 'NNP'),
#  ('Climate', 'NNP'),
#  ('Transportation', 'NNP'),
#  ('Industrials', 'NNP'),
#  ('Retail', 'NNP'),
#  ('Wealth', 'NNP'),
#  ('Life', 'NNP'),
#  ('Small', 'NNP'),
#  ('Business', 'NNP'),
#  ('Investing', 'NNP'),
#  ('Invest', 'NNP'),
#  ('In', 'IN'),
#  ('You', 'PRP'),
#  ('Personal', 'NNP'),
#  ('Finance', 'NNP'),
#  ('Fintech', 'NNP'),
#  ('Financial', 'NNP'),
#  ('Advisors', 'NNPS'),
#  ('Trading', 'NNP'),
#  ('Nation', 'NN'),
#  ('Options', 'NNP'),
#  ('Action', 'NNP'),
#  ('ETF', 'NNP'),
#  ('Street', 'NNP'),
#  ('Buffett', 'NNP'),
#  ('Archive', 'NNP'),
#  ('Earnings', 'NNP'),
#  ('Trader', 'NNP'),
#  ('Talk', 'NNP'),
#  ('Tech', 'NNP'),
#  ('Cybersecurity', 'NNP'),
#  ('Enterprise', 'NNP'),
#  ('Internet', 'NNP'),
#  ('Media', 'NNP'),
#  ('Mobile', 'NNP'),
#  ('Social', 'NNP'),
#  ('Media', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('Disruptor', 'NNP'),
#  ('50', 'CD'),
#  ('Tech', 'NNP'),
#  ('Guide', 'NNP'),
#  ('Politics', 'NNP'),
#  ('White', 'NNP'),
#  ('House', 'NNP'),
#  ('Policy', 'NN'),
#  ('Defense', 'NNP'),
#  ('Congress', 'NNP'),
#  ('Equity', 'NNP'),
#  ('and', 'CC'),
#  ('Opportunity', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('TV', 'NNP'),
#  ('Live', 'NNP'),
#  ('TV', 'NN'),
#  ('Live', 'NNP'),
#  ('Audio', 'NNP'),
#  ('Business', 'NNP'),
#  ('Day', 'NNP'),
#  ('Shows', 'VBZ'),
#  ('The', 'DT'),
#  ('News', 'NNP'),
#  ('with', 'IN'),
#  ('Shepard', 'NNP'),
#  ('Smith', 'NNP'),
#  ('Entertainment', 'NNP'),
#  ('Shows', 'NNP'),
#  ('Full', 'NNP'),
#  ('Episodes', 'NNP'),
#  ('Latest', 'NNP'),
#  ('Video', 'NNP'),
#  ('Top', 'NNP'),
#  ('Video', 'NNP'),
#  ('CEO', 'NNP'),
#  ('Interviews', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('Documentaries', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('Podcasts', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('World', 'NNP'),
#  ('Digital', 'NNP'),
#  ('Originals', 'NNP'),
#  ('Live', 'NNP'),
#  ('TV', 'NN'),
#  ('Schedule', 'NNP'),
#  ('Watchlist', 'NNP'),
#  ('PRO', 'NNP'),
#  ('Pro', 'NNP'),
#  ('News', 'NNP'),
#  ('Pro', 'NNP'),
#  ('Live', 'NNP'),
#  ('Subscribe', 'NNP'),
#  ('Sign', 'NNP'),
#  ('In', 'IN'),
#  ('Menu', 'NNP'),
#  ('Make', 'NNP'),
#  ('It', 'PRP'),
#  ('USA', 'NNP'),
#  ('INTL', 'NNP'),
#  ('watch', 'VBP'),
#  ('live', 'JJ'),
#  ('Search', 'NNP'),
#  ('quotes', 'VBZ'),
#  (',', ','),
#  ('news', 'NN'),
#  ('&', 'CC'),
#  ('videos', 'NN'),
#  ('SIGN', 'NN'),
#  ('IN', 'NNP'),
#  ('Markets', 'NNP'),
#  ('Pre-Markets', 'NNP'),
#  ('U.S.', 'NNP'),
#  ('Markets', 'NNP'),
#  ('Currencies', 'NNP'),
#  ('Cryptocurrency', 'NNP'),
#  ('Futures', 'NNP'),
#  ('&', 'CC'),
#  ('Commodities', 'NNP'),
#  ('Bonds', 'NNP'),
#  ('Funds', 'NNP'),
#  ('&', 'CC'),
#  ('ETFs', 'NNP'),
#  ('Business', 'NNP'),
#  ('Economy', 'NNP'),
#  ('Finance', 'NNP'),
#  ('Health', 'NNP'),
#  ('&', 'CC'),
#  ('Science', 'NNP'),
#  ('Media', 'NNP'),
#  ('Real', 'NNP'),
#  ('Estate', 'NNP'),
#  ('Energy', 'NNP'),
#  ('Climate', 'NNP'),
#  ('Transportation', 'NNP'),
#  ('Industrials', 'NNP'),
#  ('Retail', 'NNP'),
#  ('Wealth', 'NNP'),
#  ('Life', 'NNP'),
#  ('Small', 'NNP'),
#  ('Business', 'NNP'),
#  ('Investing', 'NNP'),
#  ('Invest', 'NNP'),
#  ('In', 'IN'),
#  ('You', 'PRP'),
#  ('Personal', 'NNP'),
#  ('Finance', 'NNP'),
#  ('Fintech', 'NNP'),
#  ('Financial', 'NNP'),
#  ('Advisors', 'NNPS'),
#  ('Trading', 'NNP'),
#  ('Nation', 'NN'),
#  ('Options', 'NNP'),
#  ('Action', 'NNP'),
#  ('ETF', 'NNP'),
#  ('Street', 'NNP'),
#  ('Buffett', 'NNP'),
#  ('Archive', 'NNP'),
#  ('Earnings', 'NNP'),
#  ('Trader', 'NNP'),
#  ('Talk', 'NNP'),
#  ('Tech', 'NNP'),
#  ('Cybersecurity', 'NNP'),
#  ('Enterprise', 'NNP'),
#  ('Internet', 'NNP'),
#  ('Media', 'NNP'),
#  ('Mobile', 'NNP'),
#  ('Social', 'NNP'),
#  ('Media', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('Disruptor', 'NNP'),
#  ('50', 'CD'),
#  ('Tech', 'NNP'),
#  ('Guide', 'NNP'),
#  ('Politics', 'NNP'),
#  ('White', 'NNP'),
#  ('House', 'NNP'),
#  ('Policy', 'NN'),
#  ('Defense', 'NNP'),
#  ('Congress', 'NNP'),
#  ('Equity', 'NNP'),
#  ('and', 'CC'),
#  ('Opportunity', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('TV', 'NNP'),
#  ('Live', 'NNP'),
#  ('TV', 'NN'),
#  ('Live', 'NNP'),
#  ('Audio', 'NNP'),
#  ('Business', 'NNP'),
#  ('Day', 'NNP'),
#  ('Shows', 'VBZ'),
#  ('The', 'DT'),
#  ('News', 'NNP'),
#  ('with', 'IN'),
#  ('Shepard', 'NNP'),
#  ('Smith', 'NNP'),
#  ('Entertainment', 'NNP'),
#  ('Shows', 'NNP'),
#  ('Full', 'NNP'),
#  ('Episodes', 'NNP'),
#  ('Latest', 'NNP'),
#  ('Video', 'NNP'),
#  ('Top', 'NNP'),
#  ('Video', 'NNP'),
#  ('CEO', 'NNP'),
#  ('Interviews', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('Documentaries', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('Podcasts', 'NNP'),
#  ('CNBC', 'NNP'),
#  ('World', 'NNP'),
#  ('Digital', 'NNP'),
#  ('Originals', 'NNP'),
#  ('Live', 'NNP'),
#  ('TV', 'NN'),
#  ('Schedule', 'NNP'),
#  ('Watchlist', 'NNP'),
#  ('PRO', 'NNP'),
#  ('Pro', 'NNP'),
#  ('News', 'NNP'),
#  ('Pro', 'NNP'),
#  ('Live', 'NNP'),
#  ('Subscribe', 'NNP'),
#  ('Sign', 'NNP'),
#  ('In', 'IN'),
#  ('Menu', 'NNP'),
#  ('Tech', 'NNP'),
#  ('Netflix', 'NNP'),
#  ("'s", 'POS'),
#  ('price', 'NN'),
#  ('hike', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ("'Catch-22", 'JJ'),
#  ("'", 'POS'),
#  ('that', 'WDT'),
#  ('actually', 'RB'),
#  ('helps', 'VBZ'),
#  ('Disney', 'NNP'),
#  ("'s", 'POS'),
#  ('upcoming', 'VBG'),
#  ('streaming', 'VBG'),
#  ('service', 'NN'),
#  ('Published', 'NNP'),
#  ('Thu', 'NNP'),
#  (',', ','),
#  ('Jan', 'NNP'),
#  ('17', 'CD'),
#  ('2019', 'CD'),
#  ('1:04', 'CD'),
#  ('PM', 'NNP'),
#  ('EST', 'NNP'),
#  ('Updated', 'NNP'),
#  ('Thu', 'NNP'),
#  (',', ','),
#  ('Jan', 'NNP'),
#  ('17', 'CD'),
#  ('2019', 'CD'),
#  ('1:42', 'CD'),
#  ('PM', 'NNP'),
#  ('EST', 'NNP'),
#  ('Tyler', 'NNP'),
#  ('Clifford', 'NNP'),
#  ('@', 'NNP'),
#  ('_TylerTheTyler_', 'NNP'),
#  ('Share', 'NNP'),
#  ('Share', 'NNP'),
#  ('Article', 'NNP'),
#  ('via', 'IN'),
#  ('Facebook', 'NNP'),
#  ('Share', 'NNP'),
#  ('Article', 'NNP'),
#  ('via', 'IN'),
#  ('Twitter', 'NNP'),
#  ('Share', 'NNP'),
#  ('Article', 'NNP'),
#  ('via', 'IN'),
#  ('LinkedIn', 'NNP'),
#  ('Share', 'NNP'),
#  ('Article', 'NNP'),
#  ('via', 'IN'),
#  ('Email', 'NNP'),
#  ('Key', 'NNP'),
#  ('Points', 'NNP'),
#  ('Netflix', 'NNP'),
#  ('subscription', 'NN'),
#  ('price', 'NN'),
#  ('hike', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('``', '``'),
#  ('key', 'JJ'),
#  ('dilemma', 'NN'),
#  ("''", "''"),
#  ('that', 'WDT'),
#  ('makes', 'VBZ'),
#  ('future', 'JJ'),
#  ('competitors', 'NNS'),
#  ('like', 'IN'),
#  ('Disney', 'NNP'),
#  ('more', 'RBR'),
#  ('viable', 'JJ'),
#  (',', ','),
#  ('New', 'NNP'),
#  ('Constructs', 'NNP'),
#  ('CEO', 'NNP'),
#  ('David', 'NNP'),
#  ('Trainer', 'NNP'),
#  ('says', 'VBZ'),
#  ('.', '.')]
#
#
#
#
# ============================ SENTENCE 2 POS TAGS ============================
#
# [('However', 'RB'),
#  (',', ','),
#  ('Aegis', 'NNP'),
#  ('Capital', 'NNP'),
#  ("'s", 'POS'),
#  ('Victory', 'NNP'),
#  ('Anthony', 'NNP'),
#  ('sees', 'VBZ'),
#  ('the', 'DT'),
#  ('Netflix', 'NNP'),
#  ('price', 'NN'),
#  ('increase', 'NN'),
#  ('as', 'IN'),
#  ('extra', 'JJ'),
#  ('money', 'NN'),
#  ('to', 'TO'),
#  ('invest', 'VB'),
#  ('in', 'IN'),
#  ('more', 'RBR'),
#  ('original', 'JJ'),
#  ('content', 'NN'),
#  ('or', 'CC'),
#  ('pad', 'VB'),
#  ('the', 'DT'),
#  ('bottom', 'JJ'),
#  ('line', 'NN'),
#  ('.', '.')]
#
#
#
#
# ============================ SENTENCE 3 POS TAGS ============================
#
# [('VIDEO', 'NNP'),
#  ('6:10', 'CD'),
#  ('06:10', 'CD'),
#  ('Netflix', 'NNP'),
#  ("'s", 'POS'),
#  ('decision', 'NN'),
#  ('to', 'TO'),
#  ('raise', 'VB'),
#  ('prices', 'NNS'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('Catch-22', 'NNP'),
#  (',', ','),
#  ('says', 'VBZ'),
#  ('New', 'NNP'),
#  ('Constructs', 'NNP'),
#  ("'", 'POS'),
#  ('David', 'NNP'),
#  ('Trainer', 'NNP'),
#  ('Closing', 'NNP'),
#  ('Bell', 'NNP'),
#  ('Disney', 'NNP'),
#  ('will', 'MD'),
#  ('have', 'VB'),
#  ('a', 'DT'),
#  ('competitive', 'JJ'),
#  ('advantage', 'NN'),
#  ('over', 'IN'),
#  ('Netflix', 'NNP'),
#  ('when', 'WRB'),
#  ('the', 'DT'),
#  ('entertainment', 'NN'),
#  ('conglomerate', 'NN'),
#  ('launches', 'VBZ'),
#  ('a', 'DT'),
#  ('competing', 'VBG'),
#  ('video', 'NN'),
#  ('streaming', 'VBG'),
#  ('platform', 'NN'),
#  ('later', 'RBR'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  (',', ','),
#  ('according', 'VBG'),
#  ('to', 'TO'),
#  ('Wall', 'NNP'),
#  ('Street', 'NNP'),
#  ('analyst', 'NN'),
#  ('David', 'NNP'),
#  ('Trainer', 'NNP'),
#  ('.', '.')]
#
#
#
#
# ============================ SENTENCE 4 POS TAGS ============================
#
# [('``', '``'),
#  ('[', 'JJ'),
#  ('Disney', 'NNP'),
#  ("'s", 'POS'),
#  (']', 'NNP'),
#  ('got', 'VBD'),
#  ('the', 'DT'),
#  ('ability', 'NN'),
#  ('to', 'TO'),
#  ('merchandise', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('another', 'DT'),
#  ('way', 'NN'),
#  ('to', 'TO'),
#  ('monetize', 'VB'),
#  ('content', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('way', 'NN'),
#  ('that', 'IN'),
#  ('Netflix', 'NNP'),
#  ('does', 'VBZ'),
#  ('not', 'RB'),
#  ('have', 'VB'),
#  (',', ','),
#  ("''", "''"),
#  ('Trainer', 'NNP'),
#  ('said', 'VBD'),
#  ('on', 'IN'),
#  ('CNBC', 'NNP'),
#  ("'s", 'POS'),
#  ('``', '``'),
#  ('Closing', 'NNP'),
#  ('Bell', 'NNP'),
#  ("''", "''"),
#  ('Wednesday', 'NNP'),
#  ('.', '.')]
#
#
#
#
# ============================ SENTENCE 5 POS TAGS ============================
#
# [('He', 'PRP'),
#  ("'s", 'VBZ'),
#  ('chief', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('New', 'NNP'),
#  ('Constructs', 'NNP'),
#  ('research', 'NN'),
#  ('firm', 'NN'),
#  ('.', '.')]
